# %% [markdown]
# <a href="https://colab.research.google.com/github/Lucasalvesdaluz/Portifolio_Analise_de_Dados/blob/main/Projeto_02_An%C3%A1lise_da_Base_de_Dados_de_Funcion%C3%A1rios_de_uma_Empresa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**🔍Descrição do Problema**
#
# Uma empresa enfrenta desafios na identificação precisa dos pontos fracos dos funcionários em diferentes níveis hierárquicos e áreas, dificultando a elaboração de treinamentos direcionados. Avaliar a performance em habilidades fundamentais como **trabalho em equipe, liderança, comunicação, iniciativa e organização** é crucial para entender quais segmentos demandam maior atenção e investimento no desenvolvimento de competências.
#
# # **🎯Objetivos da Análise**
#
# Este projeto tem como objetivo identificar os **principais pontos fracos dos funcionários em cada nível hierárquico e área da empresa**, fornecendo ao time de RH insights claros sobre as habilidades que necessitam de foco nos próximos treinamentos. Para isso, será utilizado o critério de que uma habilidade será considerada um ponto fraco quando **pelo menos 20% dos funcionários** de um determinado nível hierárquico ou área apresentarem **avaliações menores que 7 nessa habilidade**. A partir desses dados, o RH poderá priorizar ações que impactem diretamente no desempenho organizacional.
#
# # **📊Descrição da Base de Dados**
#
# Este projeto utiliza uma base de dados fictícia que representa informações sobre os funcionários de uma empresa. A base é composta por diversas colunas que abrangem dados pessoais, profissionais e de desempenho, permitindo uma análise detalhada de diferentes aspectos relacionados aos colaboradores. As colunas disponíveis são:
#
# - **Identificação e Dados Pessoais:** ID RH, Nome Completo, Estado Civil, Sexo, Data de Nascimento, Endereço.
#
# -  **Dados Contratuais:** Data de Contratação, Data de Demissão, Salário Base, Impostos, Benefícios, Vale-Transporte (VT), Vale-Refeição (VR).
#
# - **Função e Área:** Cargo, Nível, Área de Atuação.
#
# - **Dados de Férias e Horas Extras:** Férias Acumuladas, Horas Extras.
#
# - **Avaliações de Desempenho:** Imagem, Avaliação do Funcionário, Trabalho em Equipe, Liderança, Comunicação, Iniciativa, Organização.
#
# 🔗Você pode acessar e baixar a base de dados utilizada neste projeto por meio do seguinte link:
#
# [Baixar Dataset](https://lookerstudio.google.com/reporting/33aca0fb-bf21-4a34-ae8d-d6d73e0d5ceb)
#
# # **🛠️Ferramentas Utilizadas**
#
# Para explorar e analisar essa base de dados, utilizei as seguintes ferramentas e bibliotecas:
#
# - **Python:** Linguagem principal para manipulação e análise dos dados.
#
# - **Pandas:** Para leitura, limpeza e organização dos dados.
#
# - **Matplotlib:** Para a criação de gráficos e visualizações que auxiliem na análise.
#
# # **📈Relatório no Google Looker Studio**
#
# Para comunicar as principais conclusões de forma visual e prática, construí um **diagnóstico de necessidades de treinamento** no Google Looker Studio.
#
# Recomendo que ao abri-lo, você diminua o zoom do seu navegador para uma melhor visualização.
#
# 🔗Você pode acessar esse relatório completo através do link abaixo:
#
# [Diagnóstico de Necessidades de Treinamento](https://lookerstudio.google.com/reporting/33aca0fb-bf21-4a34-ae8d-d6d73e0d5ceb)
#
# Fique à vontade para explorar a análise e sugerir melhorias ou novas perguntas! 🚀

# %% [markdown]
# # **1. Inspeção Geral**
#
# O primeiro passo em qualquer projeto de análise de dados é examinar o dataframe que será explorado. Isso inclui entender suas informações, verificar o número de colunas e avaliar se os dados precisam passar por processos de limpeza ou ajustes antes de seguirmos com a análise.
#
# Também vamos importar as bibliotecas necessárias para essa análise. Utilizaremos o **Pandas** como a principal ferramenta para tratamento, transformação e análise de dados, e o **Matplotlib** como a biblioteca principal para visualização de dados.

# %% [markdown]
# **1.1 Importando bibliotecas e visualizando dataframe**

# %%
#Importando bibliotecas
import pandas as pd
import matplotlib.pyplot as plt

#Importando e visualizando DataFrame
df = pd.read_excel('/content/BaseFuncionarios.xlsx')
df.head()
# Out:
#    ID RH          Nome Completo Estado Civil Sexo Data de Nascimento  \
# 0    460         Adelino Araujo            C    M         1976-09-04
# 1      5          Adelino Gomes            C    M         1974-03-30
# 2    195        Adelino Werneck            S    M         1997-04-27
# 3    102       Adriano de Souza            C    M         1993-12-09
# 4    133  Adrielle Sá Rodrigues            S    F         1976-11-16
#
#                                             Endereço Data de Contratacao  \
# 0  Shopping Barra - Av. Centenário, 2992 - Barra,...          2005-11-07
# 1  R. Dr. Antônio Castro Prado, 422 - Vila Rossi ...          2000-03-16
# 2  Av. Borges de Medeiros, 3120 - Praia de Belas,...          2015-04-23
# 3  R. Brasílio Itiberê, 3279 - Água Verde, Curiti...          2011-12-05
# 4  R. Dr. Antônio Castro Prado, 422 - Vila Rossi ...          2001-04-25
#
#   Data de Demissao  Salario Base  Impostos  ...            Área  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 494 entries, 0 to 493
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID RH                     494 non-null    int64
#  1   Nome Completo             494 non-null    object
#  2   Estado Civil              494 non-null    object
#  3   Sexo                      494 non-null    object
#  4   Data de Nascimento        494 non-null    datetime64[ns]
#  5   Endereço                  494 non-null    object
#  6   Data de Contratacao       494 non-null    datetime64[ns]
#  7   Data de Demissao          62 non-null     datetime64[ns]
#  8   Salario Base              494 non-null    int64
#  9   Impostos                  494 non-null    float64
#  10  Beneficios                494 non-null    float64
#  11  VT                        494 non-null    float64
#  12  VR                        494 non-null    float64
# ...

# %% [markdown]
# A base de dados original possui **25 colunas**, mas para este projeto focaremos apenas nas avaliações das habilidades comportamentais dos funcionários. Manteremos as colunas relacionadas a trabalho em equipe, liderança, comunicação, iniciativa e organização.
#
# Essa filtragem será realizada na etapa de tratamento de dados, garantindo que trabalharemos apenas com as informações mais relevantes para nossa análise.

# %% [markdown]
# **1.2 Verificando inconsistências**
#
# Agora, vamos analisar a base de dados em busca de possíveis inconsistências. Primeiro, verificaremos se há duplicações nos números de ID dos funcionários. Em seguida, analisaremos a existência de valores nulos nas colunas que contêm as avaliações das habilidades.

# %%
#Verificando a existência de duplicatas
display(df['ID RH'].duplicated().sum())
# Out:
# 0

# %%
#Verificando a existência de valores nulos
display(df.isnull().sum())
# Out:
# ID RH                         0
# Nome Completo                 0
# Estado Civil                  0
# Sexo                          0
# Data de Nascimento            0
# Endereço                      0
# Data de Contratacao           0
# Data de Demissao            432
# Salario Base                  0
# Impostos                      0
# Beneficios                    0
# VT                            0
# VR                            0
# Cargo                         0
# Nível                         0
# Área                          0
# Ferias Acumuladas             0
# Horas Extras                  0
# Imagem                      450
# Avaliação do Funcionário      0
# Trabalho em Equipe            0
# Liderança                     0
# Comunicação                   0
# Iniciativa                    0
# Organização                   0
# dtype: int64

# %% [markdown]
# Após a análise, constatamos que não há valores duplicados na coluna de ID dos funcionários, e as colunas relacionadas às habilidades avaliadas não apresentam valores nulos. Dessa forma, não há necessidade imediata de realizar limpeza nos dados que serão utilizados.

# %% [markdown]
# # **2. Transformação dos Dados**

# %% [markdown]
# Para garantir o sucesso da nossa análise, é essencial criar novas variáveis que filtrem apenas as colunas e valores relevantes. Precisaremos criar:
#
# - Uma lista contendo o percentual de funcionários com notas abaixo de 7 por nível nível hierárquico.
# - Outra lista semelhante, obtendo o percentual de funcionários com notas abaixo de 7 por área de atuação.

# %% [markdown]
# **2.1 Obtendo o percentual de funcionários com notas abaixo de 7 por nível hierárquico**

# %% [markdown]
# Começaremos contando a quantidade de avaliações abaixo de 7 em cada uma das habilidades comportamentais de acordo com o nível hierárquico correspondente.
#
# Em seguida, dividiremos esse total pela quantidade total de funcionários do respectivo nível hierárquico para cada habilidade. O resultado será multiplicado por 100 para obter o percentual correspondente.
#
# Por fim, reuniremos todos esses percentuais em uma lista.
#
# Veja esse processo sendo aplicado com os estagiários da empresa:

# %%
percentual_estagiarios=[]
nivel=df[df['Nível']=='Estagiário'][['Trabalho em Equipe','Liderança','Comunicação','Iniciativa','Organização']]
qtd_estagiarios=len(nivel)

#Percentual de estágiarios com pontuação menor que 7 no quesito trabalho em equipe
percentual_estagiarios.append((nivel[nivel['Trabalho em Equipe']<7]['Trabalho em Equipe'].count()/qtd_estagiarios*100).round(2))

#Percentual de estagiários com pontuação menor que 7 no quesito liderança
percentual_estagiarios.append((nivel[nivel['Liderança']<7]['Liderança'].count()/qtd_estagiarios*100).round(2))

#Percentual de estagiários com pontuação menor que 7 no quesito comunicação
percentual_estagiarios.append((nivel[nivel['Comunicação']<7]['Comunicação'].count()/qtd_estagiarios*100).round(2))

#Percentual de estagiários com pontuação menor que 7 no quesito iniciativa
percentual_estagiarios.append((nivel[nivel['Iniciativa']<7]['Iniciativa'].count()/qtd_estagiarios*100).round(2))

#Percentual de estagiários com pontuação menor que 7 no quesito organização
percentual_estagiarios.append((nivel[nivel['Organização']<7]['Organização'].count()/qtd_estagiarios*100).round(2))

#Lista contendo os percentual de avaliações abaixo de 7 dos estagiários em cada habilidade comportamental
percentual_estagiarios
# Out:
# [14.19, 8.39, 20.65, 7.1, 12.9]

# %% [markdown]
# Aplicaremos o mesmo procedimento descrito anteriormente para os demais níveis. **Ao final, cada nível hierárquico terá sua própria lista contendo os percentuais de avaliações abaixo de 7 em cada habilidade comportamental.**
#
# Confira a aplicação desse processo nas células a seguir.

# %%
percentual_analistas=[]
nivel=df[df['Nível']=='Analista'][['Trabalho em Equipe','Liderança','Comunicação','Iniciativa','Organização']]
qtd_analistas=len(nivel)

#Percentual de coordenadores com pontuação menor que 7 no quesito trabalho em equipe
percentual_analistas.append((nivel[nivel['Trabalho em Equipe']<7]['Trabalho em Equipe'].count()/qtd_analistas*100).round(2))

#Percentual de coordenadores com pontuação menor que 7 no quesito liderança
percentual_analistas.append((nivel[nivel['Liderança']<7]['Liderança'].count()/qtd_analistas*100).round(2))

#Percentual de coordenadores com pontuação menor que 7 no quesito comunicação
percentual_analistas.append((nivel[nivel['Comunicação']<7]['Comunicação'].count()/qtd_analistas*100).round(2))

#Percentual de coordenadores com pontuação menor que 7 no quesito iniciativa
percentual_analistas.append((nivel[nivel['Iniciativa']<7]['Iniciativa'].count()/qtd_analistas*100).round(2))

#Percentual de coordenadores com pontuação menor que 7 no quesito organização
percentual_analistas.append((nivel[nivel['Organização']<7]['Organização'].count()/qtd_analistas*100).round(2))

#Lista contendo os percentual de avaliações abaixo de 7 dos analistas em cada habilidade comportamental
percentual_analistas
# Out:
# [15.15, 12.12, 17.58, 12.12, 11.52]

# %%
percentual_coordenadores=[]
nivel=df[df['Nível']=='Coordenador'][['Trabalho em Equipe','Liderança','Comunicação','Iniciativa','Organização']]
qtd_coordenadores=len(nivel)

#Percentual de coordenadores com pontuação menor que 7 no quesito trabalho em equipe
percentual_coordenadores.append((nivel[nivel['Trabalho em Equipe']<7]['Trabalho em Equipe'].count()/qtd_coordenadores*100).round(2))

#Percentual de coordenadores com pontuação menor que 7 no quesito liderança
percentual_coordenadores.append((nivel[nivel['Liderança']<7]['Liderança'].count()/qtd_coordenadores*100).round(2))

#Percentual de coordenadores com pontuação menor que 7 no quesito comunicação
percentual_coordenadores.append((nivel[nivel['Comunicação']<7]['Comunicação'].count()/qtd_coordenadores*100).round(2))

#Percentual de coordenadores com pontuação menor que 7 no quesito iniciativa
percentual_coordenadores.append((nivel[nivel['Iniciativa']<7]['Iniciativa'].count()/qtd_coordenadores*100).round(2))

#Percentual de coordenadores com pontuação menor que 7 no quesito organização
percentual_coordenadores.append((nivel[nivel['Organização']<7]['Organização'].count()/qtd_coordenadores*100).round(2))

#Lista contendo os percentual de avaliações abaixo de 7 dos coordenadores em cada habilidade comportamental
percentual_coordenadores
# Out:
# [24.39, 11.38, 31.71, 4.88, 16.26]

# %%
percentual_gerentes=[]
nivel=df[df['Nível']=='Gerente'][['Trabalho em Equipe','Liderança','Comunicação','Iniciativa','Organização']]
qtd_gerentes=len(nivel)

#Percentual de coordenadores com pontuação menor que 7 no quesito trabalho em equipe
percentual_gerentes.append((nivel[nivel['Trabalho em Equipe']<7]['Trabalho em Equipe'].count()/qtd_gerentes*100).round(2))

#Percentual de coordenadores com pontuação menor que 7 no quesito liderança
percentual_gerentes.append((nivel[nivel['Liderança']<7]['Liderança'].count()/qtd_gerentes*100).round(2))

#Percentual de coordenadores com pontuação menor que 7 no quesito comunicação
percentual_gerentes.append((nivel[nivel['Comunicação']<7]['Comunicação'].count()/qtd_gerentes*100).round(2))

#Percentual de coordenadores com pontuação menor que 7 no quesito iniciativa
percentual_gerentes.append((nivel[nivel['Iniciativa']<7]['Iniciativa'].count()/qtd_gerentes*100).round(2))

#Percentual de coordenadores com pontuação menor que 7 no quesito organização
percentual_gerentes.append((nivel[nivel['Organização']<7]['Organização'].count()/qtd_gerentes*100).round(2))

#Lista contendo os percentual de avaliações abaixo de 7 dos gerentes em cada habilidade comportamental
percentual_gerentes
# Out:
# [26.09, 6.52, 19.57, 8.7, 21.74]

# %%
percentual_diretores=[]
nivel=df[df['Nível']=='Diretor'][['Trabalho em Equipe','Liderança','Comunicação','Iniciativa','Organização']]
qtd_diretores=len(nivel)

#Percentual de coordenadores com pontuação menor que 7 no quesito trabalho em equipe
percentual_diretores.append((nivel[nivel['Trabalho em Equipe']<7]['Trabalho em Equipe'].count()/qtd_diretores*100).round(2))

#Percentual de coordenadores com pontuação menor que 7 no quesito liderança
percentual_diretores.append((nivel[nivel['Liderança']<7]['Liderança'].count()/qtd_diretores*100).round(2))

#Percentual de coordenadores com pontuação menor que 7 no quesito comunicação
percentual_diretores.append((nivel[nivel['Comunicação']<7]['Comunicação'].count()/qtd_diretores*100).round(2))

#Percentual de coordenadores com pontuação menor que 7 no quesito iniciativa
percentual_diretores.append((nivel[nivel['Iniciativa']<7]['Iniciativa'].count()/qtd_diretores*100).round(2))

#Percentual de coordenadores com pontuação menor que 7 no quesito organização
percentual_diretores.append((nivel[nivel['Organização']<7]['Organização'].count()/qtd_diretores*100).round(2))

#Lista contendo os percentual de avaliações abaixo de 7 dos diretores em cada habilidade comportamental
percentual_diretores
# Out:
# [20.0, 0.0, 20.0, 0.0, 40.0]

# %% [markdown]
# Após concluirmos todo o processo, obtivemos as seguintes listas: `percentual_estagiarios`, `percentual_analistas`, `percentual_coordenadores`, `percentual_gerentes` e `percentual_diretores`. Cada uma delas contendo os percentuais de avaliações abaixo de 7 em cada habilidade comportamental.
#
# Agora, iremos consolidar essas listas em uma única variável chamada `percentuais_nivel`. Além disso, criaremos duas outras variáveis:
#
# - `niveis_hierarquicos`, que armazenará todos os níveis hierárquicos da empresa.
# - `requisitos`, que conterá as habilidades comportamentais avaliadas.
#
# Essas variáveis desempenharão um papel fundamental na análise exploratória.

# %%
percentuais_nivel = [percentual_estagiarios, percentual_analistas, percentual_coordenadores, percentual_gerentes, percentual_diretores]
niveis_hierarquicos = ['Estagiários', 'Analistas', 'Coordenadores', 'Gerentes', 'Diretores']
requesitos = ['Tb.Equipe', 'Liderança', 'Comunicação', 'Iniciativa', 'Organização']

# %% [markdown]
# **2.2 Obtendo o percentual de funcionários com notas abaixo de 7 por área de atuação**

# %% [markdown]
# De forma similar ao procedimento anterior, agora iremos contar a quantidade de avaliações abaixo de 7 em cada uma das habilidades, desta vez considerando as áreas da empresa.
#
# Em seguida, dividiremos esse número pelo total de funcionários da respectiva área para cada habilidade e, então, multiplicaremos o resultado por 100 para calcular o percentual.
#
# Por fim, organizaremos esses percentuais em uma lista.
#
# Veja esse processo sendo aplicado aos funcionários da área administrativa da empresa.

# %%
percentual_administrativo=[]
area=df[df['Área']=='Administrativo'][['Trabalho em Equipe','Liderança','Comunicação','Iniciativa','Organização']]
qtd_administrativo=len(area)

#Percentual de estágiarios com pontuação menor que 7 no quesito trabalho em equipe
percentual_administrativo.append((area[area['Trabalho em Equipe']<7]['Trabalho em Equipe'].count()/qtd_administrativo*100).round(2))

#Percentual de estagiários com pontuação menor que 7 no quesito liderança
percentual_administrativo.append((area[area['Liderança']<7]['Liderança'].count()/qtd_administrativo*100).round(2))

#Percentual de estagiários com pontuação menor que 7 no quesito comunicação
percentual_administrativo.append((area[area['Comunicação']<7]['Comunicação'].count()/qtd_administrativo*100).round(2))

#Percentual de estagiários com pontuação menor que 7 no quesito iniciativa
percentual_administrativo.append((area[area['Iniciativa']<7]['Iniciativa'].count()/qtd_administrativo*100).round(2))

#Percentual de estagiários com pontuação menor que 7 no quesito organização
percentual_administrativo.append((area[area['Organização']<7]['Organização'].count()/qtd_administrativo*100).round(2))

percentual_administrativo
# Out:
# [19.44, 11.11, 20.37, 6.48, 11.11]

# %% [markdown]
# Aplicaremos o mesmo procedimento descrito anteriormente para as demais áreas. **Ao final, cada área da empresa terá sua própria lista contendo os percentuais de avaliações abaixo de 7 em cada habilidade comportamental**.
#
# Confira a aplicação desse processo nas células a seguir.

# %%
percentual_operacoes=[]
area=df[df['Área']=='Operações'][['Trabalho em Equipe','Liderança','Comunicação','Iniciativa','Organização']]
qtd_operacoes=len(area)

#Percentual de estágiarios com pontuação menor que 7 no quesito trabalho em equipe
percentual_operacoes.append((area[area['Trabalho em Equipe']<7]['Trabalho em Equipe'].count()/qtd_operacoes*100).round(2))

#Percentual de estagiários com pontuação menor que 7 no quesito liderança
percentual_operacoes.append((area[area['Liderança']<7]['Liderança'].count()/qtd_operacoes*100).round(2))

#Percentual de estagiários com pontuação menor que 7 no quesito comunicação
percentual_operacoes.append((area[area['Comunicação']<7]['Comunicação'].count()/qtd_operacoes*100).round(2))

#Percentual de estagiários com pontuação menor que 7 no quesito iniciativa
percentual_operacoes.append((area[area['Iniciativa']<7]['Iniciativa'].count()/qtd_operacoes*100).round(2))

#Percentual de estagiários com pontuação menor que 7 no quesito organização
percentual_operacoes.append((area[area['Organização']<7]['Organização'].count()/qtd_operacoes*100).round(2))

percentual_operacoes
# Out:
# [14.15, 6.6, 22.64, 7.55, 20.75]

# %%
percentual_comercial=[]
area=df[df['Área']=='Comercial'][['Trabalho em Equipe','Liderança','Comunicação','Iniciativa','Organização']]
qtd_comercial=len(area)

#Percentual de estágiarios com pontuação menor que 7 no quesito trabalho em equipe
percentual_comercial.append((area[area['Trabalho em Equipe']<7]['Trabalho em Equipe'].count()/qtd_comercial*100).round(2))

#Percentual de estagiários com pontuação menor que 7 no quesito liderança
percentual_comercial.append((area[area['Liderança']<7]['Liderança'].count()/qtd_comercial*100).round(2))

#Percentual de estagiários com pontuação menor que 7 no quesito comunicação
percentual_comercial.append((area[area['Comunicação']<7]['Comunicação'].count()/qtd_comercial*100).round(2))

#Percentual de estagiários com pontuação menor que 7 no quesito iniciativa
percentual_comercial.append((area[area['Iniciativa']<7]['Iniciativa'].count()/qtd_comercial*100).round(2))

#Percentual de estagiários com pontuação menor que 7 no quesito organização
percentual_comercial.append((area[area['Organização']<7]['Organização'].count()/qtd_comercial*100).round(2))

percentual_comercial
# Out:
# [16.04, 6.6, 19.81, 7.55, 14.15]

# %%
percentual_logistica=[]
area=df[df['Área']=='Logística'][['Trabalho em Equipe','Liderança','Comunicação','Iniciativa','Organização']]
qtd_logistica=len(area)

#Percentual de estágiarios com pontuação menor que 7 no quesito trabalho em equipe
percentual_logistica.append((area[area['Trabalho em Equipe']<7]['Trabalho em Equipe'].count()/qtd_logistica*100).round(2))

#Percentual de estagiários com pontuação menor que 7 no quesito liderança
percentual_logistica.append((area[area['Liderança']<7]['Liderança'].count()/qtd_logistica*100).round(2))

#Percentual de estagiários com pontuação menor que 7 no quesito comunicação
percentual_logistica.append((area[area['Comunicação']<7]['Comunicação'].count()/qtd_logistica*100).round(2))

#Percentual de estagiários com pontuação menor que 7 no quesito iniciativa
percentual_logistica.append((area[area['Iniciativa']<7]['Iniciativa'].count()/qtd_logistica*100).round(2))

#Percentual de estagiários com pontuação menor que 7 no quesito organização
percentual_logistica.append((area[area['Organização']<7]['Organização'].count()/qtd_logistica*100).round(2))

percentual_logistica
# Out:
# [22.22, 12.22, 26.67, 12.22, 12.22]

# %%
percentual_financeiro=[]
area=df[df['Área']=='Financeiro'][['Trabalho em Equipe','Liderança','Comunicação','Iniciativa','Organização']]
qtd_financeiro=len(area)

#Percentual de estágiarios com pontuação menor que 7 no quesito trabalho em equipe
percentual_financeiro.append((area[area['Trabalho em Equipe']<7]['Trabalho em Equipe'].count()/qtd_financeiro*100).round(2))

#Percentual de estagiários com pontuação menor que 7 no quesito liderança
percentual_financeiro.append((area[area['Liderança']<7]['Liderança'].count()/qtd_financeiro*100).round(2))

#Percentual de estagiários com pontuação menor que 7 no quesito comunicação
percentual_financeiro.append((area[area['Comunicação']<7]['Comunicação'].count()/qtd_financeiro*100).round(2))

#Percentual de estagiários com pontuação menor que 7 no quesito iniciativa
percentual_financeiro.append((area[area['Iniciativa']<7]['Iniciativa'].count()/qtd_financeiro*100).round(2))

#Percentual de estagiários com pontuação menor que 7 no quesito organização
percentual_financeiro.append((area[area['Organização']<7]['Organização'].count()/qtd_financeiro*100).round(2))

percentual_financeiro
# Out:
# [20.24, 15.48, 22.62, 8.33, 13.1]

# %% [markdown]
# Após concluirmos todo o processo, obtivemos as seguintes listas: `percentual_administrativo`, `percentual_operacoes`, `percentual_comercial`, `percentual_logistica`, `percentual_financeiro`. Cada uma delas contendo os percentuais de avaliações abaixo de 7 de cada habilidade comportamental.
#
# Agora, iremos consolidar essas listas em uma única variável chamada `percentuais_area`. Além disso, criaremos uma variável chamada `area_atuacao`, que armazenará todos os nomes de todas as áreas da empresa.

# %%
area_atuacao = ['Administrativo', 'Operações', 'Comercial', 'Logística', 'Financeiro']
percentuais_area = [percentual_administrativo, percentual_operacoes, percentual_comercial, percentual_logistica, percentual_financeiro]

# %% [markdown]
# # **3. Análise Exploratória**
#
# Feito isso, podemos partir para análise exploratória dos dados afim de respondermos de fato o desafio proposto.  Apenas recaptulando, precisamos identificar os níveis hierárquicos e áreas que possuem pelo menos 20% dos funcionários com notas abaixo de 7 em alguma habilidade e, após isso, identificar quais habilidades são essas para que possamos passar para o setor de RH.

# %% [markdown]
# **3.1 Pontos críticos por nível hierárquico**
#
# Começando pelo nível hierárquico, vamos exibir 5 gráficos de barras, onde cada gráfico representará um nível da empresa e cada barra representará o percentual de funcionários que possuem notas abaixo de 7 em alguma habilidade.
#
# As barras de cor laranja são as habilidades que possuem pelo menos 20% dos funcionários com notas abaixo de 7.
#
# Veja isso através do código abaixo.

# %%
fig,axs=plt.subplots(ncols=3,nrows=2,figsize=(40,20))
axs = axs.flatten()

for i, niveis in enumerate(niveis_hierarquicos):
  barras = axs[i].bar(requesitos, percentuais_nivel[i])
  #Títulos dos gráficos
  axs[i].set_title(niveis_hierarquicos[i],fontsize=35,pad=20)

  for spine in axs[i].spines.values():
    spine.set_visible(False)
  #Removendo ticks
  axs[i].tick_params(axis='x',length=0,labelsize=20)
  axs[i].tick_params(axis='y',length=0,labelsize=20,labelcolor='grey')
  #Inserindo os valores das barras
  axs[i].bar_label(barras,percentuais_nivel[i],padding=2, fontsize=20,fontweight='bold')
  #Definindo valores do eixo y
  axs[i].set_yticks([20,40,60,80,100])
  #Destacando as barras com valor maior ou igual a 20%
  for c in range(len(barras)):
    if percentuais_nivel[i][c] >= 20:
      barras[c].set_color('orange')




#Título Principal
fig.suptitle('Pontos Críticos | Nível Hierárquico', fontsize=50, fontweight='bold')
# Ajustando o espaçamento vertical entre os gráficos
plt.subplots_adjust(hspace=0.2)
#Removendo o gráfico vazio
fig.delaxes(axs[5])
plt.show()

# %% [markdown]
# A partir dos gráficos acima, podemos concluir os seguintes pontos:
#
# - **Estagiários**: O principal desafio é na área de comunicação, com o maior percentual de avaliações abaixo de 7.
# - **Analistas:** Estão próximos ao limite crítico de 20% em comunicação, indicando a necessidade de atenção especial nessa habilidade.
# - **Coordenadores:** Apresentam um sério problema de comunicação, sendo o nível hierárquico com o maior percentual nessa habilidade, além de dificuldades em trabalho em equipe.
# - **Gerentes:** Demonstram baixo desempenho em organização e trabalho em equipe. Ademais, o percentual de comunicação está em 19,57%, próximo ao limite crítico de 20%.
# - **Diretores:** Apresentam deficiências em três áreas: trabalho em equipe, comunicação e organização. A organização é o ponto mais crítico, com o maior percentual entre suas habilidades e em comparação com os outros níveis hierárquicos.

# %% [markdown]
# **3.2 Pontos críticos por área de atuação**
#
# Vamos realizar a mesma visualização do tópico anterior para observar os pontos críticos da área de atuação.

# %%
fig,axs=plt.subplots(ncols=3,nrows=2,figsize=(40,20))
axs = axs.flatten()

for i, areas in enumerate(area_atuacao):
  barras = axs[i].bar(requesitos, percentuais_area[i])
  #Títulos dos gráficos
  axs[i].set_title(area_atuacao[i],fontsize=35,pad=20)

  for spine in axs[i].spines.values():
    spine.set_visible(False)
  #Removendo ticks
  axs[i].tick_params(axis='x',length=0,labelsize=20)
  axs[i].tick_params(axis='y',length=0,labelsize=20,labelcolor='grey')
  #Inserindo os valores das barras
  axs[i].bar_label(barras,percentuais_area[i],padding=2, fontsize=20,fontweight='bold')
  #Definindo valores do eixo y
  axs[i].set_yticks([20,40,60,80,100])
  #Destacando em laranja os valores iguais ou maiores que 20
  for c in range(len(barras)):
    if percentuais_area[i][c] >= 20:
      barras[c].set_color('orange')

#Título Principal
fig.suptitle('Pontos Críticos | Área de Atuação', fontsize=50, fontweight='bold')
# Ajustando o espaçamento vertical entre os gráficos
plt.subplots_adjust(hspace=0.2)
#Removendo o gráfico vazio
fig.delaxes(axs[5])
plt.show()

# %% [markdown]
# Com base nos dados analisados, podemos chegar às seguintes conclusões:
#
# - **Administrativo:** Apresenta dificuldades em comunicação e está com o percentual de trabalho em equipe próximo ao limite crítico de 20%.
# - **Operações:** Enfrenta problemas significativos em comunicação e organização.
# - **Comercial:** O percentual de avaliações em comunicação está prestes a atingir o limite de 20%, indicando um ponto de atenção.
# - **Logística:** Apresenta desafios tanto em trabalho em equipe quanto em comunicação.
# - **Financeiro:** Enfrenta problemas relacionados a trabalho em equipe e comunicação.

# %% [markdown]
# # **4. Conclusões Finais**
#
# **Trabalho em Equipe:**
#
# - **Níveis Hierárquicos:** Necessário implementar ações corretivas para coordenadores, gerentes e diretores, que apresentam percentuais críticos.
# - **Áreas:** Treinamentos são recomendados para as equipes de logística e financeiro, que já atingiram o limite de 20%. O setor administrativo também demanda atenção, pois está próximo desse percentual e requer medidas preventivas.
#
# **Comunicação:**
#
#  - Recomenda-se a realização de treinamentos abrangendo todos os níveis hierárquicos e áreas da empresa. Mesmo onde o percentual crítico não foi alcançado, os valores estão perigosamente elevados, sinalizando um risco iminente.
#
# **Organização:**
#
# - **Níveis Hierárquicos:** Ações de melhoria são indicadas para gerentes e diretores, que apresentaram baixo desempenho nessa habilidade.
# - **Áreas:** Necessário priorizar o desenvolvimento organizacional na área do financeiro, onde os índices são preocupantes.

# %% [markdown]
# # **5. Diagnóstico de Necessidades de Treinamento**
# Não se esqueça que preparei um relatório exclusivo no Google Looker Studio com um Diagnóstico de Necessidades de Treinamento que apresenta as principais conclusões dessa análise.
#
# 🔗Acesso-o através do link abaixo:
#
# [Acessar relatório](https://lookerstudio.google.com/reporting/33aca0fb-bf21-4a34-ae8d-d6d73e0d5ceb)
#
# Lembre-se de diminuir o zoom do seu navegador para uma melhor experiência.
